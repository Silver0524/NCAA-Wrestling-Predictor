# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from collections import defaultdict

# %%
raw = pd.read_csv('../data/raw/d1_all_match_results.csv')
raw
# Out:
#         season   date                        event  is_dual_meet  \
# 0         2014  03/08           EIWA Championships         False
# 1         2014  03/08           EIWA Championships         False
# 2         2014  02/08    Princeton - Boston U Dual          True
# 3         2014  02/02   Boston U - Binghamton Dual          True
# 4         2014  01/25      Harvard - Boston U Dual          True
# ...        ...    ...                          ...           ...
# 439444    2025  11/23  Utah Valley - NC State Dual          True
# 439445    2025  11/03        Battle at The Citadel         False
# 439446    2025  11/03        Battle at The Citadel         False
# 439447    2025  11/03        Battle at The Citadel         False
# 439448    2025  11/03        Battle at The Citadel         False
#
#         weight_class result result_type   score          opponent  \
# 0                125      W         DEC   5 - 4  Caleb Richardson
# 1                125      L        FALL    2:48       David Terao
# 2                125      W          MD  12 - 0         Ryan Cash
# 3                125      L         DEC   9 - 6       David White
# 4                125      W          MD  15 - 5         Max Mejia
# ...              ...    ...         ...     ...               ...
# 439444           197      L          MD  14 - 3       Kael Bennie
# 439445           197      L        MFOR   0 - 0       Vincent Lee
# 439446           197      W         DEC   8 - 3       Kwasi Bonsu
# 439447           197      W          MD  15 - 3       Gunnar Pool
# 439448           197      L         INJ    3:31    Patrick Brophy
#
#         opponent_id    opponent_school        wrestler  wrestler_id  \
# 0             12113       Pennsylvania  Chris McGinley        12050
# 1             12068           American  Chris McGinley        12050
# 2             12045          Princeton  Chris McGinley        12050
# 3             21963         Binghamton  Chris McGinley        12050
# 4             17866            Harvard  Chris McGinley        12050
# ...             ...                ...             ...          ...
# 439444        84802        Utah Valley     Chase Horne        72952
# 439445        93063               Duke     Chase Horne        72952
# 439446        84783               Duke     Chase Horne        72952
# 439447        82480  Appalachian State     Chase Horne        72952
# 439448        78688        The Citadel     Chase Horne        72952
#
#        wrestler_school
# 0             Boston U
# 1             Boston U
# 2             Boston U
# 3             Boston U
# 4             Boston U
# ...                ...
# 439444        Nc State
# 439445        Nc State
# 439446        Nc State
# 439447        Nc State
# 439448        Nc State
#
# [439449 rows x 14 columns]

# %%
raw[['score1', 'score2']] = raw['score'].str.split(' - ', expand=True)

raw['wrestler_score'] = np.where(raw['result'] == 'W', raw['score1'], 
                       np.where(raw['result'] == 'L', raw['score2'], 0))
raw['opponent_score'] = np.where(raw['result'] == 'W', raw['score2'], 
                       np.where(raw['result'] == 'L', raw['score1'], 0))

raw = raw.drop(['score1', 'score2'], axis=1)
raw

# %%
raw['wrestler_score'] = np.where(raw['result_type'] != 'FALL', raw['wrestler_score'], 0)
raw['opponent_score'] = np.where(raw['result_type'] != 'FALL', raw['opponent_score'], 0)

# %%
raw = raw.drop(['score'], axis=1)
raw

# %%
raw['is_dual_meet'] = [True if x == 'Dual' else False for x in raw['event']]
